# %% [markdown]
# ### 440Hz sin波

# %%
# %run -i calc_fft.py sinwave_440hz.wav 0 1024
# Out:
# 分析対象ファイル：sinwave_440hz.wav
# データ開始位置： 0
# サンプル数： 1024
# チャンネル数： 1
# 振幅範囲： 32768.0
# サンプリング周波数： 44100

# %% [markdown]
# ### ピアノ A4

# %%
# %run -i calc_fft.py piano_a4.wav 13000 1024
# Out:
# 分析対象ファイル：piano_a4.wav
# データ開始位置： 13000
# サンプル数： 1024
# チャンネル数： 2
# 振幅範囲： 32768.0
# サンプリング周波数： 44100
